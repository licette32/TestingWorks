# %% [markdown]
# #  **TESTING 2** 🔍

# %% [markdown]
# Nombre: **Beverly J. L. Gonzalez Casanova**

# %% [markdown]
# ## 📝 Tarea - Clase 2
#
# Resolución de la función Test para `determinarTriangulo`.
# Definición arbitraria de la función “`determinarTriangulo`”: devuelve 1 si es isósceles, 2 si es escaleno y 3 si es equilátero.
# La función `test` devuelve 1 si está OK, devuelve 0 si ERROR.
#
#
#
# ### Desafío extra
#
# Tomando de base el ejercicio anterior de la función “`determinarTriangulo`” incorporar dentro de su código la verificación de si realmente los tres lados del triángulo corresponden con un triángulo, es decir, con un polígono.

# %% [markdown]
# ## 🎯 Objetivo
# Resolver la función test para verificar el correcto funcionamiento de la función determinarTriangulo.
#
# <br>
#
# ### 🛠️ Instrucciones
#
# * Definir la función `determinarTriangulo(lado1, lado2, lado3)`, que debe:
#
# 🔹 Devolver 1 si el triángulo es isósceles (dos lados iguales).
#
# 🔹 Devolver 2 si el triángulo es escaleno (todos los lados distintos).
#
# 🔹 Devolver 3 si el triángulo es equilátero (todos los lados iguales).
#
# <br>
#
# ![lados.png](data:image/png;base64,...)
#
# <br>
#
# * Definir la función `test()`, que debe:
#
# ✅ Devolver 1 si la función determinarTriangulo pasa todas las pruebas correctamente.
#
# ❌ Devolver 0 si alguna prueba falla.

# %% [markdown]
# ## 📐 Función determinarTriangulo con Python

# %%
# Se define la función determinarTriangulo
def determinarTriangulo(a, b, c):
    """
    Determina el tipo de triángulo dado sus lados a, b y c.
    Retornar:
        1 --> Isósceles
        2 --> Escaleno
        3 --> Equilátero
    """
    if a == b == c:
        return 3
    elif a == b or a == c or b == c:
        return 1
    else:
        return 2

# DEfino la función test
def test():
    """
    Función de prueba para la función determinarTriangulo.
    Imprime el resultado de cada prueba y un resumen final.
    """
    # Casos de prueba
    casos_prueba = [
        #(a, b, c)
        (5, 5, 5),  # Equilátero
        (6, 2, 6),  # Isósceles
        (6, 7, 8),  # Escaleno
        (1, 2, 1),  # Equilátero
        (2, 8, 3),  # Isósceles
        (5, 6, 7)   # Escaleno
    ]

    resultados_esperados = [3, 1, 2, 3, 1, 2]

    todo_ok = True  # Bandera para saber si todo salió bien

    for i in range(len(casos_prueba)):
        a, b, c = casos_prueba[i]
        resultado = determinarTriangulo(a, b, c)
        if resultado == resultados_esperados[i]:
            print(f"✅ Caso {i+1}: ({a}, {b}, {c}) -> Correcto")
        else:
            print(f"❌ Caso {i+1}: ({a}, {b}, {c}) -> Error: esperado {resultados_esperados[i]}, obtenido {resultado}")
            todo_ok = False

    # Resumen final
    if todo_ok:
        print("\n🎉 Todos los casos de prueba pasaron correctamente.")
        return 1
    else:
        print("\n⚠️ Hubo errores en algunas pruebas.")
        return 0

# --- Llamamos a test ---
test()
# Out:
# ✅ Caso 1: (5, 5, 5) -> Correcto
# ✅ Caso 2: (6, 2, 6) -> Correcto
# ✅ Caso 3: (6, 7, 8) -> Correcto
# ❌ Caso 4: (1, 2, 1) -> Error: esperado 3, obtenido 1
# ❌ Caso 5: (2, 8, 3) -> Error: esperado 1, obtenido 2
# ✅ Caso 6: (5, 6, 7) -> Correcto
#
# ⚠️ Hubo errores en algunas pruebas.
# 0

# %%
# Se define la función determinarTriangulo
def determinarTriangulo(a, b, c):
    """
    Determina el tipo de triángulo dado sus lados a, b y c.
    Retornar:
        1 --> Isósceles
        2 --> Escaleno
        3 --> Equilátero
    """
    if a == b == c:
        return 3
    elif a == b or a == c or b == c:
        return 1
    else:
        return 2

# Defino la función test
def test():
    """
    Función de prueba para determinarTriangulo.
    Imprime el resultado de cada prueba y un resumen final.
    """
    # Casos de prueba
    casos_prueba = [
        (5, 5, 5),  # Equilátero
        (6, 2, 6),  # Isósceles
        (6, 7, 8),  # Escaleno
        (1, 1, 1),  # Equilátero
        (2, 2, 3),  # Isósceles
        (5, 6, 7)   # Escaleno
    ]

    resultados_esperados = [3, 1, 2, 3, 1, 2]

    todo_ok = True  # Bandera para saber si todo salió bien

    for i in range(len(casos_prueba)):
        a, b, c = casos_prueba[i]
        resultado = determinarTriangulo(a, b, c)
        if resultado == resultados_esperados[i]:
            print(f"✅ Caso {i+1}: ({a}, {b}, {c}) -> Correcto")
        else:
            print(f"❌ Caso {i+1}: ({a}, {b}, {c}) -> Error: esperado {resultados_esperados[i]}, obtenido {resultado}")
            todo_ok = False

    # Resumen final
    if todo_ok:
        print("\n🎉 Todos los casos de prueba pasaron correctamente.")
        return 1
    else:
        print("\n⚠️ Hubo errores en algunas pruebas.")
        return 0

# --- Llamamos a test ---
test()
# Out:
# ✅ Caso 1: (5, 5, 5) -> Correcto
# ✅ Caso 2: (6, 2, 6) -> Correcto
# ✅ Caso 3: (6, 7, 8) -> Correcto
# ✅ Caso 4: (1, 1, 1) -> Correcto
# ✅ Caso 5: (2, 2, 3) -> Correcto
# ✅ Caso 6: (5, 6, 7) -> Correcto
#
# 🎉 Todos los casos de prueba pasaron correctamente.
# 1

# %% [markdown]
# ### 🌟 Desafío Extra en Python

# %% [markdown]
# 🧠 ¿Cuál es la condición de existencia de un triángulo?
#
# Un conjunto de tres lados forma un triángulo si y solo si:
#
# 𝑎 + 𝑏 > 𝑐 ,
#
# 𝑎 + 𝑐 > 𝑏 ,
#
# 𝑏 + 𝑐 > 𝑎
#
#
# Es decir:
#
# ✔ La suma de dos lados debe ser mayor al tercer lado.
#
# ✔ Esto debe cumplirse para las tres combinaciones.
#
# <br>
#
# 🛠️ Nuevo diseño de la función
#
# Ahora nuestra función `determinarTriangulo` debe:
#
# 1. Primero verificar si los lados forman un triángulo real.
#
# 2. Si NO forman un triángulo, retornar -1 (o lo que vos quieras definir).
#
# 3. Si forman un triángulo, clasificar (equilátero, isósceles, escaleno) como antes.

# %%
# --- Función determinarTriangulo mejorada con validación de triángulo ---
def determinarTriangulo(a, b, c):
    """
    Determina el tipo de triángulo dado sus lados a, b y c.
    Retornar:
        -1 --> No forman un triángulo válido
         1 --> Isósceles
         2 --> Escaleno
         3 --> Equilátero
    """
    # Validar si es un triángulo real
    if (a + b <= c) or (a + c <= b) or (b + c <= a):
        return -1  # No es un triángulo válido

    # Clasificar el tipo de triángulo
    if a == b == c:
        return 3  # Equilátero
    elif a == b or a == c or b == c:
        return 1  # Isósceles
    else:
        return 2  # Escaleno

# --- Función de test mejorada ---
def test():
    """
    Función de prueba para determinarTriangulo.
    Imprime el resultado de cada prueba y un resumen final.
    """
    # Casos de prueba
    casos_prueba = [
        (5, 5, 5),   # Equilátero
        (6, 2, 6),   # Isósceles
        (6, 7, 8),   # Escaleno
        (1, 1, 3),   # No forma triángulo
        (2, 2, 3),   # Isósceles
        (10, 1, 1)   # No forma triángulo
    ]

    resultados_esperados = [3, 1, 2, -1, 1, -1]

    todo_ok = True

    for i in range(len(casos_prueba)):
        a, b, c = casos_prueba[i]
        resultado = determinarTriangulo(a, b, c)
        if resultado == resultados_esperados[i]:
            print(f"✅ Caso {i+1}: ({a}, {b}, {c}) -> Correcto")
        else:
            print(f"❌ Caso {i+1}: ({a}, {b}, {c}) -> Error: esperado {resultados_esperados[i]}, obtenido {resultado}")
            todo_ok = False

    # Resumen final
    if todo_ok:
        print("\n🎉 Todos los casos de prueba pasaron correctamente.")
        return 1
    else:
        print("\n⚠️ Hubo errores en algunas pruebas.")
        return 0

# --- Ejecutamos ---
test()
# Out:
# ✅ Caso 1: (5, 5, 5) -> Correcto
# ✅ Caso 2: (6, 2, 6) -> Correcto
# ✅ Caso 3: (6, 7, 8) -> Correcto
# ✅ Caso 4: (1, 1, 3) -> Correcto
# ✅ Caso 5: (2, 2, 3) -> Correcto
# ✅ Caso 6: (10, 1, 1) -> Correcto
#
# 🎉 Todos los casos de prueba pasaron correctamente.
# 1

# %% [markdown]
# Qué cambia con esto?
#
# Antes, cualquier combinación se clasificaba como triángulo, en cambio ahora se clasifican combinaciones válidas. Ahora, con la validación detectamos si los lados no forman un triángulo (antes no detectábamos errores de lados).

# %% [markdown]
# ## 📐 Función determinarTriangulo con R

# %%
# !pip install -q rpy2

# %%
# %load_ext rpy2.ipython

# %%
# %%R
# # Función para determinar el tipo de triángulo
# determinar_triangulo <- function(a, b, c) {
#   if (a == b && b == c) {
#     return(3)  # Equilátero
#   }
#   else if (a == b || a == c || b == c) {
#     return(1)  # Isósceles
#   }
#   else {
#     return(2)  # Escaleno
#   }
# }
#
# # Función de prueba para verificar la implementación
# test_triangulo <- function() {
#   # Definimos nuestros casos de prueba
#   casos_prueba <- list(
#     list(a = 2, b = 2, c = 2, esperado = 3),               # Equilátero
#     list(a = 3, b = 3, c = 4, esperado = 1),               # Isósceles
#     list(a = 3, b = 4, c = 5, esperado = 2),               # Escaleno
#     list(a = 5, b = 5, c = 5, esperado = 3),               # Equilátero
#     list(a = 4, b = 4, c = 6, esperado = 1),               # Isósceles
#     list(a = 7, b = 8, c = 9, esperado = 2)                # Escaleno
#   )
#
#   # Probamos cada uno de los casos
#   for (caso in casos_prueba) {
#     resultado <- determinar_triangulo(caso$a, caso$b, caso$c)
#     if (resultado != caso$esperado) {
#       cat(sprintf("❌ Error con (%d, %d, %d): esperado %d, obtenido %d\n",
#                  caso$a, caso$b, caso$c, caso$esperado, resultado))
#       return(FALSE)
#     }
#   }
#
#   cat("✅ Todos los tests pasaron correctamente\n")
#   return(TRUE)
# }
#
# # Ejecutamos los tests
# test_triangulo()
# Out:
# ✅ Todos los tests pasaron correctamente
# [1] TRUE

# %%
# %%R
# # Función con validación
# determinarTriangulo <- function(a, b, c) {
#   # Retorna:
#   #  -1 --> No forman un triángulo válido
#   #   1 --> Isósceles
#   #   2 --> Escaleno
#   #   3 --> Equilátero
#
#   # Validar si los lados forman un triángulo real
#   if (a + b <= c || a + c <= b || b + c <= a) {
#     return(-1) # No es un triángulo válido
#   }
#
#   # Clasificar el tipo de triángulo
#   if (a == b && b == c) {
#     return(3) # Equilátero
#   } else if (a == b || a == c || b == c) {
#     return(1) # Isósceles
#   } else {
#     return(2) # Escaleno
#   }
# }
#
# # Función test
# test <- function() {
#   # Función de prueba para determinarTriangulo
#
#   casos_prueba <- list(
#     c(5, 9, 5),   # Equilátero
#     c(6, 2, 6),   # Isósceles
#     c(6, 7, 8),   # Escaleno
#     c(1, 1, 6),   # No forman triángulo
#     c(2, 2, 3),   # Isósceles
#     c(10, 1, 1)   # No forman triángulo
#   )
#
#   resultados_esperados <- c(3, 1, 2, -1, 1, -1)
#
#   todo_ok <- TRUE
#
#   for (i in 1:length(casos_prueba)) {
#     lados <- casos_prueba[[i]]
#     resultado <- determinarTriangulo(lados[1], lados[2], lados[3])
#     if (resultado == resultados_esperados[i]) {
#       cat(sprintf("✅ Caso %d: (%d, %d, %d) -> Correcto\n", i, lados[1], lados[2], lados[3]))
#     } else {
#       cat(sprintf("❌ Caso %d: (%d, %d, %d) -> Error: esperado %d, obtenido %d\n",
#                   i, lados[1], lados[2], lados[3], resultados_esperados[i], resultado))
#       todo_ok <- FALSE
#     }
#   }
#
#   if (todo_ok) {
#     cat("\n🎉 Todos los casos de prueba pasaron correctamente.\n")
#     return(1)
#   } else {
#     cat("\n⚠️ Hubo errores en algunas pruebas.\n")
#     return(0)
#   }
# }
#
# # Ejecutar pruebas
# test()
# Out:
# ❌ Caso 1: (5, 9, 5) -> Error: esperado 3, obtenido 1
# ✅ Caso 2: (6, 2, 6) -> Correcto
# ✅ Caso 3: (6, 7, 8) -> Correcto
# ✅ Caso 4: (1, 1, 6) -> Correcto
# ✅ Caso 5: (2, 2, 3) -> Correcto
# ✅ Caso 6: (10, 1, 1) -> Correcto
#
# ⚠️ Hubo errores en algunas pruebas.
# [1] 0
